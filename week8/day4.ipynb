# %% [markdown]
# # The Price is Right
#
# First we'll polish off 2 more simple agents:
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# Then we'll put it all together into an Agent Framework.
#
# For the Push Notification, we will be using a nifty platform called Pushover.
# You'll need to set up a free account and add 2 tokens to your `.env` file:
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
load_dotenv(override=True)
DB = "products_vectorstore"

# %%
# initialize logging
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
agent = MessagingAgent()
# Out:
# INFO:root:[Messaging Agent] Messaging Agent is initializing
# INFO:root:[Messaging Agent] Messaging Agent has initialized Pushover

# %%
agent.push("MASSIVE NEWS!!!")
# Out:
# INFO:root:[Messaging Agent] Messaging Agent is sending a push notification
# INFO:root:[Messaging Agent] Pushover notification sent successfully: 200 OK

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Additional resource: more sophisticated planning agent</h2>
#             <span style="color:#f71;">The Planning Agent that we use in the next cell is simply a python script that calls the other Agents; frankly that's all we require for this project. But if you're intrigued to see a more Autonomous version in which we give the Planning Agent tools and allow it to decide which Agents to call, see my implementation of <a href="https://github.com/ed-donner/agentic/blob/main/workshop/price_agents/autonomous_planning_agent.py">AutonomousPlanningAgent</a> in my related repo, <a href="https://github.com/ed-donner/agentic">Agentic</a>. This is an example with multiple tools that dynamically decides which function to call.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent
# Out:
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# INFO:datasets:PyTorch version 2.8.0 available.

# %%
planner = PlanningAgent(collection)
# Out:
# INFO:root:[Planning Agent] Planning Agent is initializing
# INFO:root:[Scanner Agent] Scanner Agent is initializing
# INFO:root:[Scanner Agent] Scanner Agent is ready
# INFO:root:[Ensemble Agent] Initializing Ensemble Agent
# INFO:root:[Specialist Agent] Specialist Agent is initializing - connecting to modal
# INFO:root:[Specialist Agent] Specialist Agent is ready
# INFO:root:[Frontier Agent] Initializing Frontier Agent
# INFO:root:[Frontier Agent] Frontier Agent is set up with DeepSeek
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:root:[Frontier Agent] Frontier Agent is ready
# INFO:root:[Random Forest Agent] Random Forest Agent is initializing
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:root:[Random Forest Agent] Random Forest Agent is ready
# INFO:root:[Ensemble Agent] Ensemble Agent is ready
# INFO:root:[Messaging Agent] Messaging Agent is initializing
# INFO:root:[Messaging Agent] Messaging Agent has initialized Pushover
# INFO:root:[Planning Agent] Planning Agent is ready

# %%
planner.plan()
# Out:
# INFO:root:[Planning Agent] Planning Agent is kicking off a run
# INFO:root:[Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# INFO:root:[Scanner Agent] Scanner Agent received 50 deals not already scraped
# INFO:root:[Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $60.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $49.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $163.49
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $74.44
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $58.44
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $60.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $59.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $178.06
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $77.20
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $44.20
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $950.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $3499.00
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $222.09
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $1727.17
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $228.17
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $89.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $129.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $272.57
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $118.45
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $18.45
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $350.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $799.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $252.17
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $493.05
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $-6.95
# INFO:root:[Planning Agent] Planning Agent has identified the best deal has discount $228.17
# INFO:root:[Messaging Agent] Messaging Agent is sending a push notification
# INFO:root:[Messaging Agent] Pushover notification sent successfully: 200 OK
# INFO:root:[Messaging Agent] Messaging Agent has completed
# INFO:root:[Planning Agent] Planning Agent has completed a run
# Opportunity(deal=Deal(product_description='The Jackery HomePower 3000 Solar Generator combined with the SolarSaga 200W Solar Panel 2-Pack is a powerful energy solution for both home and outdoor use. The generator boasts a massive 3,024Wh capacity and can charge in just 2.4 hours, providing a peak power output of 3,000W. This kit comes complete with two 200W solar panels, making it an ideal choice for eco-friendly energy solutions. This package is perfect for camping, emergency power, or those looking to reduce their carbon footprint without sacrificing convenience.', price=1499.0, url='https://www.dealnews.com/Jackery-Home-Power-3000-Solar-Generator-Solar-Saga-200-W-Solar-Panel-2-Pack-for-1499-free-shipping/21783349.html?iref=rss-c142'), estimate=1727.1682368161114, discount=228.1682368161114)
